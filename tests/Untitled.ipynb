# %%
import pandas as pd

# %%
data = pd.read_json("http://localhost:3001/api/expression?symbol=KRAS")

# %%
data
# Out:
#                                   celllinename  expression  \
# 0                  LN18_CENTRAL_NERVOUS_SYSTEM    9.781221
# 1                                  769P_KIDNEY   10.241690
# 2                                  786O_KIDNEY   10.350120
# 3                                  CAOV3_OVARY    9.341495
# 4                                  HEPG2_LIVER    9.562099
# 5     MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE   10.898580
# 6                                 NCIH524_LUNG   10.399190
# 7                                 NCIH209_LUNG   10.544760
# 8                            MIAPACA2_PANCREAS   10.430520
# 9                                   MCAS_OVARY   10.668150
# 10                                   SBC5_LUNG   10.339390
# 11                                COLO829_SKIN    9.971065
# 12                               VCAP_PROSTATE   11.363800
# 13                               COLO704_OVARY   10.174020
# 14                                 IPC298_SKIN   10.083280
# ...
