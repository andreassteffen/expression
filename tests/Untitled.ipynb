# %%
import pandas as pd

# %%
data = pd.read_json("http://localhost:3001/api/expression?symbol=KRAS")

# %%
pd.DataFrame().pivot()

# %%
data.groupby('site_primary').describe().reset_index().pivot(index = 'site_primary', columns = 'level_1', values = 'expression').reset_index().to_dict(orient = 'records')
# Out:
# [{'25%': 10.71824,
#   '50%': 10.8286,
#   '75%': 11.23165,
#   'count': 17.0,
#   'max': 11.9361,
#   'mean': 10.891166470588233,
#   'min': 10.04085,
#   'site_primary': u'autonomic_ganglia',
#   'std': 0.5031505541701853},
#  {'25%': 10.526724999999999,
#   '50%': 11.421690000000002,
#   '75%': 13.133547499999999,
#   'count': 8.0,
#   'max': 14.15655,
#   'mean': 11.803186,
#   'min': 9.568468,
#   'site_primary': u'biliary_tract',
#   'std': 1.7020264466912878},
#  {'25%': 10.3862,
#   '50%': 10.537510000000001,
#   '75%': 10.647160000000001,
#   'count': 29.0,
#   'max': 11.06295,
#   'mean': 10.5306405862069,
#   'min': 9.876597,
#   'site_primary': u'bone',
#   'std': 0.24441447385530488},
#  {'25%': 10.183415,
#   '50%': 10.379489999999999,
#   '75%': 10.72039,
#   'count': 59.0,
#   'max': 11.85983,
#   'mean': 10.427507881355929,
#   'min': 8.623885000000001,
#   'site_primary': u'breast',
#   'std': 0.5718048147284985},
#  {'25%': 9.722975,
#   '50%': 9.998928,
# ...

# %%
data.groupby('site_primary').describe

# %%
pd.DataFrame().to_json
