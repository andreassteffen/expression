# %%
import pandas as pd

# %%
data = pd.read_json("http://localhost:3001/expression?symbol=KRAS")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-6-5aaec946a599> in <module>()
# ----> 1 data = pd.read_json("http://localhost:3001/expression?symbol=KRAS")
#
# /Library/Python/2.7/site-packages/pandas/io/json.pyc in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit)
#     185     """
#     186
# --> 187     filepath_or_buffer, _, _ = get_filepath_or_buffer(path_or_buf)
#     188     if isinstance(filepath_or_buffer, compat.string_types):
#     189         try:
#
# /Library/Python/2.7/site-packages/pandas/io/common.pyc in get_filepath_or_buffer(filepath_or_buffer, encoding, compression)
#     275
#     276     if _is_url(filepath_or_buffer):
# --> 277         req = _urlopen(str(filepath_or_buffer))
#     278         if compression == 'infer':
# ...

# %%
data
# Out:
#       annotation_id                              celllinename  expression  \
# 0               490               LN18_CENTRAL_NERVOUS_SYSTEM    9.781221
# 1                12                               769P_KIDNEY   10.241690
# 2                13                               786O_KIDNEY   10.350120
# 3                92                               CAOV3_OVARY    9.341495
# 4               280                               HEPG2_LIVER    9.562099
# 5               570  MOLT4_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE   10.898580
# 6               675                              NCIH524_LUNG   10.399190
# 7               641                              NCIH209_LUNG   10.544760
# 8               552                         MIAPACA2_PANCREAS   10.430520
# 9               521                                MCAS_OVARY   10.668150
# 10              810                                 SBC5_LUNG   10.339390
# 11              132                              COLO829_SKIN    9.971065
# ...
